# %% [markdown]
# <a href="https://colab.research.google.com/github/IDISAI/Daily-AI-Exercise/blob/main/Day%2001/naming_more.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### [Storing Information: Variables](https://colab.research.google.com/github/AIVIETNAM-AIO-HUYTRUONG/AI/blob/main/01.Python%20Programming%20Fundamentals/chapter_2_python_basics_variables%2C_data_types%2C_and_operators.ipynb#scrollTo=K3OD7z2YRrcj)
# - Trong bài tập này bạn sẽ làm quen với câu lệnh hiển thị ra màn hình print, cách tạo biến, đặt tên biến đúng cách trong Python

# %% [markdown]
# 1. Bạn hãy tạo file và đặt tên file bất kỳ nhưng tên phải được viết thường và mỗi từ cách nhau bởi dấu gạch dưới `"_"`, ví dụ như `simple_message.ipynb`. Sau đó hãy lập trình in chuỗi `"Hello world!"` ra màn hình.

# %%
# Câu 1
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### [Naming Variables: Rules and Conventions](https://colab.research.google.com/github/AIVIETNAM-AIO-HUYTRUONG/AI/blob/main/01.Python%20Programming%20Fundamentals/chapter_2_python_basics_variables%2C_data_types%2C_and_operators.ipynb#scrollTo=m51Yn-hdYAlm&line=1&uniqifier=1)

# %% [markdown]
# 2. Gán một chuỗi `"Have a nice day!"` vào biến `message`. Sau đó sử dụng câu lệnh `print` để hiển thị biến này ra màn hình.

# %%
# Câu 2
message = "Have a nice day!"
print(message)
# Out:
# Have a nice day!

# %% [markdown]
# 3. Bạn hãy tạo một chuỗi `"Let's have Tet holidays!"` và gán vào biến với tên `1_message`. Sau đó sử dụng câu lệnh `print` để hiển thị biến này ra màn hình. Nếu kết quả hiển thị thông báo lỗi, hãy xác định lỗi này là gì và sửa như thế nào? Sau đó chạy lại chương trình.

# %%
# Câu 3
1_message = "Let's have Tet holidays!"
print(1_message)
# Out:
#   File "/tmp/ipykernel_3628/2289007401.py", line 2
#     1_message = "Let's have Tet holidays!"
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# - Đoạn code trên xuất hiện thông báo lỗi cú pháp tạo dòng thứ 2, lỗi này là do chúng ta đã đặt tên biến không đúng quy tắc trong Python.
# - Để sửa lỗi thì chúng ta cần đặt lại tên biến đúng ví dụ như: `message`, `message_1` chẳng hạn.

# %%
# Câu 3
message_1 = "Let's have Tet holidays!"
print(message_1)
# Out:
# Let's have Tet holidays!
